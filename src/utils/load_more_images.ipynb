# %%
import os
from urllib.parse import urlparse
import h5py
import cv2
import numpy as np
import pandas as pd
from PIL import Image
from pathlib import Path
import matplotlib.pyplot as plt

from kaggleisic import config
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# === Paths ===
image_folder = urlparse(str(config.RAW_DATA_DIR / "ISIC-images")).path
metadata_file = urlparse(str(config.RAW_DATA_DIR / "ISIC-images/metadata.csv")).path
train_meta_file = config.RAW_DATA_DIR / "new-train-metadata.csv"
train_hdf5_file = urlparse(str(config.RAW_DATA_DIR / "train-image.hdf5")).path

output_hdf5 = urlparse(str(config.INTERIM_DATA_DIR / "combined-image.hdf5")).path
output_hdf5_train = urlparse(str(config.INTERIM_DATA_DIR / "train-image.hdf5")).path
output_meta = urlparse(str(config.INTERIM_DATA_DIR / "combined-metadata.csv")).path

resize_shape = (224, 224)

# %%
# === 1. Load ISIC metadata and assign cancer label (1) ===
print("📥 Loading new cancer metadata...")
isic_metadata = pd.read_csv(metadata_file)[["isic_id"]]
isic_metadata["target"] = 1

# === 2. Load original benign metadata (target = 0) ===
print("📥 Loading benign metadata from existing train file...")
original_metadata = pd.read_csv(train_meta_file)[["isic_id", "target"]]
benign_metadata = original_metadata[original_metadata["target"] == 0]
# Out:
# 📥 Loading new cancer metadata...
# 📥 Loading benign metadata from existing train file...
# /var/folders/g9/kxkk4qgj7b51026tpb72p1x40000gn/T/ipykernel_68068/1259415478.py:8: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_metadata = pd.read_csv(train_meta_file)[["isic_id", "target"]]

# %%
# === 3. Combine metadata and save to CSV ===
combined_metadata = pd.concat([benign_metadata, isic_metadata], ignore_index=True)
combined_metadata.to_csv(output_meta, index=False)
print(f"✅ Saved combined metadata: {output_meta}")
# Out:
# ✅ Saved combined metadata: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/interim/combined-metadata.csv

# %%
# === 4. Append new cancer images into HDF5 ===
print(f"📦 Appending cancer images to {output_hdf5_train}...")

with h5py.File(output_hdf5_train, "a") as hf:
    for _, row in isic_metadata.iterrows():
        isic_id = row["isic_id"]
        img_path = Path(image_folder) / f"{isic_id}.jpg"

        if isic_id in hf:
            print(f"⚠️ Skipping duplicate: {isic_id}")
            continue
        if not img_path.exists():
            print(f"❌ Missing file: {img_path}")
            continue

        try:
            img = Image.open(img_path).convert("RGB").resize(resize_shape)
            img_np = np.asarray(img)
            if img_np.shape != (224, 224, 3):
                print(f"❌ Invalid shape for {isic_id}: {img_np.shape}")
                continue
            hf.create_dataset(isic_id, data=img_np, compression="gzip")
        except Exception as e:
            print(f"❌ Error processing {isic_id}: {e}")

print("✅ Done updating HDF5 with new images.")
# Out:
# 📦 Appending cancer images to /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/interim/train-image.hdf5...
# ⚠️ Skipping duplicate: ISIC_0000002
# ⚠️ Skipping duplicate: ISIC_0000004
# ⚠️ Skipping duplicate: ISIC_0000013
# ⚠️ Skipping duplicate: ISIC_0096034
# ⚠️ Skipping duplicate: ISIC_0104229
# ⚠️ Skipping duplicate: ISIC_0119495
# ⚠️ Skipping duplicate: ISIC_0157834
# ⚠️ Skipping duplicate: ISIC_0190307
# ⚠️ Skipping duplicate: ISIC_0211092
# ⚠️ Skipping duplicate: ISIC_0220459
# ⚠️ Skipping duplicate: ISIC_0238218
# ⚠️ Skipping duplicate: ISIC_0279372
# ⚠️ Skipping duplicate: ISIC_0287900
# ⚠️ Skipping duplicate: ISIC_0293670
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_0302225.jpg
# ⚠️ Skipping duplicate: ISIC_0321944
# ⚠️ Skipping duplicate: ISIC_0330452
# ⚠️ Skipping duplicate: ISIC_0338720
# ⚠️ Skipping duplicate: ISIC_0386460
# ⚠️ Skipping duplicate: ISIC_0392749
# ⚠️ Skipping duplicate: ISIC_0429895
# ⚠️ Skipping duplicate: ISIC_0445144
# ⚠️ Skipping duplicate: ISIC_0452332
# ⚠️ Skipping duplicate: ISIC_0467830
# ⚠️ Skipping duplicate: ISIC_0521019
# ⚠️ Skipping duplicate: ISIC_0527743
# ⚠️ Skipping duplicate: ISIC_0554252
# ⚠️ Skipping duplicate: ISIC_0565021
# ⚠️ Skipping duplicate: ISIC_0638180
# ⚠️ Skipping duplicate: ISIC_0664135
# ⚠️ Skipping duplicate: ISIC_0664841
# ⚠️ Skipping duplicate: ISIC_0699524
# ⚠️ Skipping duplicate: ISIC_0704481
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_0757385.jpg
# ⚠️ Skipping duplicate: ISIC_0760004
# ⚠️ Skipping duplicate: ISIC_0763691
# ⚠️ Skipping duplicate: ISIC_0770686
# ⚠️ Skipping duplicate: ISIC_0793445
# ⚠️ Skipping duplicate: ISIC_0811515
# ⚠️ Skipping duplicate: ISIC_0814829
# ⚠️ Skipping duplicate: ISIC_0848536
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_0912126.jpg
# ⚠️ Skipping duplicate: ISIC_0918465
# ⚠️ Skipping duplicate: ISIC_1020240
# ⚠️ Skipping duplicate: ISIC_1034966
# ⚠️ Skipping duplicate: ISIC_1063394
# ⚠️ Skipping duplicate: ISIC_1071492
# ⚠️ Skipping duplicate: ISIC_1096940
# ⚠️ Skipping duplicate: ISIC_1105843
# ⚠️ Skipping duplicate: ISIC_1105887
# ⚠️ Skipping duplicate: ISIC_1111537
# ⚠️ Skipping duplicate: ISIC_1135529
# ⚠️ Skipping duplicate: ISIC_1141528
# ⚠️ Skipping duplicate: ISIC_1145601
# ⚠️ Skipping duplicate: ISIC_1186361
# ⚠️ Skipping duplicate: ISIC_1217551
# ⚠️ Skipping duplicate: ISIC_1246526
# ⚠️ Skipping duplicate: ISIC_1257488
# ⚠️ Skipping duplicate: ISIC_1262710
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_1273748.jpg
# ⚠️ Skipping duplicate: ISIC_1357366
# ⚠️ Skipping duplicate: ISIC_1377023
# ⚠️ Skipping duplicate: ISIC_1480614
# ⚠️ Skipping duplicate: ISIC_1540514
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_1550822.jpg
# ⚠️ Skipping duplicate: ISIC_1621074
# ⚠️ Skipping duplicate: ISIC_1623236
# ⚠️ Skipping duplicate: ISIC_1640109
# ⚠️ Skipping duplicate: ISIC_1645097
# ⚠️ Skipping duplicate: ISIC_1662809
# ⚠️ Skipping duplicate: ISIC_1694963
# ⚠️ Skipping duplicate: ISIC_1741809
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_1767451.jpg
# ⚠️ Skipping duplicate: ISIC_1786961
# ⚠️ Skipping duplicate: ISIC_1935982
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_2013933.jpg
# ⚠️ Skipping duplicate: ISIC_2023222
# ⚠️ Skipping duplicate: ISIC_2027124
# ⚠️ Skipping duplicate: ISIC_2031355
# ⚠️ Skipping duplicate: ISIC_2043443
# ⚠️ Skipping duplicate: ISIC_2068746
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_2081308.jpg
# ⚠️ Skipping duplicate: ISIC_2090145
# ⚠️ Skipping duplicate: ISIC_2090244
# ⚠️ Skipping duplicate: ISIC_2138706
# ⚠️ Skipping duplicate: ISIC_2235682
# ⚠️ Skipping duplicate: ISIC_2263885
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_2266761.jpg
# ⚠️ Skipping duplicate: ISIC_2318247
# ⚠️ Skipping duplicate: ISIC_2346081
# ⚠️ Skipping duplicate: ISIC_2396582
# ⚠️ Skipping duplicate: ISIC_2439617
# ⚠️ Skipping duplicate: ISIC_2480600
# ⚠️ Skipping duplicate: ISIC_2538516
# ⚠️ Skipping duplicate: ISIC_2577098
# ⚠️ Skipping duplicate: ISIC_2581432
# ⚠️ Skipping duplicate: ISIC_2604412
# ⚠️ Skipping duplicate: ISIC_2742835
# ⚠️ Skipping duplicate: ISIC_2746016
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_2749588.jpg
# ⚠️ Skipping duplicate: ISIC_2764227
# ⚠️ Skipping duplicate: ISIC_2787880
# ⚠️ Skipping duplicate: ISIC_2857123
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_2936926.jpg
# ⚠️ Skipping duplicate: ISIC_2943219
# ⚠️ Skipping duplicate: ISIC_3039686
# ⚠️ Skipping duplicate: ISIC_3091180
# ⚠️ Skipping duplicate: ISIC_3093714
# ⚠️ Skipping duplicate: ISIC_3121355
# ⚠️ Skipping duplicate: ISIC_3164288
# ⚠️ Skipping duplicate: ISIC_3167797
# ⚠️ Skipping duplicate: ISIC_3201295
# ⚠️ Skipping duplicate: ISIC_3266736
# ⚠️ Skipping duplicate: ISIC_3288933
# ⚠️ Skipping duplicate: ISIC_3374114
# ⚠️ Skipping duplicate: ISIC_3377793
# ⚠️ Skipping duplicate: ISIC_3398012
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_3429122.jpg
# ⚠️ Skipping duplicate: ISIC_3445540
# ⚠️ Skipping duplicate: ISIC_3467026
# ⚠️ Skipping duplicate: ISIC_3467445
# ⚠️ Skipping duplicate: ISIC_3481735
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_3496887.jpg
# ⚠️ Skipping duplicate: ISIC_3498683
# ⚠️ Skipping duplicate: ISIC_3501835
# ⚠️ Skipping duplicate: ISIC_3521698
# ⚠️ Skipping duplicate: ISIC_3581982
# ⚠️ Skipping duplicate: ISIC_3585149
# ⚠️ Skipping duplicate: ISIC_3631780
# ⚠️ Skipping duplicate: ISIC_3646371
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_3657289.jpg
# ⚠️ Skipping duplicate: ISIC_3705092
# ⚠️ Skipping duplicate: ISIC_3721080
# ⚠️ Skipping duplicate: ISIC_3762456
# ⚠️ Skipping duplicate: ISIC_3780711
# ⚠️ Skipping duplicate: ISIC_3825991
# ⚠️ Skipping duplicate: ISIC_3831348
# ⚠️ Skipping duplicate: ISIC_3832733
# ⚠️ Skipping duplicate: ISIC_3894462
# ⚠️ Skipping duplicate: ISIC_3921012
# ⚠️ Skipping duplicate: ISIC_3929736
# ⚠️ Skipping duplicate: ISIC_3951022
# ⚠️ Skipping duplicate: ISIC_3957869
# ⚠️ Skipping duplicate: ISIC_3964079
# ⚠️ Skipping duplicate: ISIC_4023678
# ⚠️ Skipping duplicate: ISIC_4027733
# ⚠️ Skipping duplicate: ISIC_4114301
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_4237031.jpg
# ⚠️ Skipping duplicate: ISIC_4252342
# ⚠️ Skipping duplicate: ISIC_4308153
# ⚠️ Skipping duplicate: ISIC_4363101
# ⚠️ Skipping duplicate: ISIC_4384129
# ⚠️ Skipping duplicate: ISIC_4416759
# ⚠️ Skipping duplicate: ISIC_4425681
# ⚠️ Skipping duplicate: ISIC_4495069
# ⚠️ Skipping duplicate: ISIC_4558229
# ⚠️ Skipping duplicate: ISIC_4586629
# ⚠️ Skipping duplicate: ISIC_4591437
# ⚠️ Skipping duplicate: ISIC_4603466
# ⚠️ Skipping duplicate: ISIC_4614975
# ⚠️ Skipping duplicate: ISIC_4620217
# ⚠️ Skipping duplicate: ISIC_4629159
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_4652160.jpg
# ⚠️ Skipping duplicate: ISIC_4654372
# ⚠️ Skipping duplicate: ISIC_4659886
# ⚠️ Skipping duplicate: ISIC_4676617
# ⚠️ Skipping duplicate: ISIC_4700100
# ⚠️ Skipping duplicate: ISIC_4750368
# ⚠️ Skipping duplicate: ISIC_4820306
# ⚠️ Skipping duplicate: ISIC_4843324
# ⚠️ Skipping duplicate: ISIC_4851249
# ⚠️ Skipping duplicate: ISIC_4867539
# ⚠️ Skipping duplicate: ISIC_4882116
# ⚠️ Skipping duplicate: ISIC_4883996
# ⚠️ Skipping duplicate: ISIC_4907011
# ⚠️ Skipping duplicate: ISIC_4924870
# ⚠️ Skipping duplicate: ISIC_4927574
# ⚠️ Skipping duplicate: ISIC_4938448
# ⚠️ Skipping duplicate: ISIC_4954780
# ⚠️ Skipping duplicate: ISIC_4974104
# ⚠️ Skipping duplicate: ISIC_5033787
# ⚠️ Skipping duplicate: ISIC_5035525
# ⚠️ Skipping duplicate: ISIC_5039397
# ⚠️ Skipping duplicate: ISIC_5042859
# ⚠️ Skipping duplicate: ISIC_5043386
# ⚠️ Skipping duplicate: ISIC_5077618
# ⚠️ Skipping duplicate: ISIC_5143941
# ⚠️ Skipping duplicate: ISIC_5190198
# ⚠️ Skipping duplicate: ISIC_5193169
# ⚠️ Skipping duplicate: ISIC_5204454
# ⚠️ Skipping duplicate: ISIC_5206103
# ⚠️ Skipping duplicate: ISIC_5213811
# ⚠️ Skipping duplicate: ISIC_5225958
# ⚠️ Skipping duplicate: ISIC_5297885
# ⚠️ Skipping duplicate: ISIC_5303524
# ⚠️ Skipping duplicate: ISIC_5328578
# ⚠️ Skipping duplicate: ISIC_5359616
# ⚠️ Skipping duplicate: ISIC_5366444
# ⚠️ Skipping duplicate: ISIC_5400739
# ⚠️ Skipping duplicate: ISIC_5419141
# ⚠️ Skipping duplicate: ISIC_5475654
# ⚠️ Skipping duplicate: ISIC_5489626
# ⚠️ Skipping duplicate: ISIC_5498814
# ⚠️ Skipping duplicate: ISIC_5536448
# ⚠️ Skipping duplicate: ISIC_5542071
# ⚠️ Skipping duplicate: ISIC_5583714
# ⚠️ Skipping duplicate: ISIC_5609822
# ⚠️ Skipping duplicate: ISIC_5624290
# ⚠️ Skipping duplicate: ISIC_5643847
# ⚠️ Skipping duplicate: ISIC_5661573
# ⚠️ Skipping duplicate: ISIC_5668270
# ⚠️ Skipping duplicate: ISIC_5677120
# ⚠️ Skipping duplicate: ISIC_5757798
# ⚠️ Skipping duplicate: ISIC_5762031
# ⚠️ Skipping duplicate: ISIC_5783485
# ⚠️ Skipping duplicate: ISIC_5814779
# ⚠️ Skipping duplicate: ISIC_5832006
# ⚠️ Skipping duplicate: ISIC_5875571
# ⚠️ Skipping duplicate: ISIC_5879031
# ⚠️ Skipping duplicate: ISIC_5956582
# ⚠️ Skipping duplicate: ISIC_5987936
# ⚠️ Skipping duplicate: ISIC_5990594
# ⚠️ Skipping duplicate: ISIC_5999336
# ⚠️ Skipping duplicate: ISIC_6001603
# ⚠️ Skipping duplicate: ISIC_6016458
# ⚠️ Skipping duplicate: ISIC_6025411
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_6045985.jpg
# ⚠️ Skipping duplicate: ISIC_6068699
# ⚠️ Skipping duplicate: ISIC_6095295
# ⚠️ Skipping duplicate: ISIC_6149388
# ⚠️ Skipping duplicate: ISIC_6166598
# ⚠️ Skipping duplicate: ISIC_6177157
# ⚠️ Skipping duplicate: ISIC_6184108
# ⚠️ Skipping duplicate: ISIC_6218923
# ⚠️ Skipping duplicate: ISIC_6246414
# ⚠️ Skipping duplicate: ISIC_6249729
# ⚠️ Skipping duplicate: ISIC_6255931
# ⚠️ Skipping duplicate: ISIC_6269100
# ⚠️ Skipping duplicate: ISIC_6294286
# ⚠️ Skipping duplicate: ISIC_6302481
# ⚠️ Skipping duplicate: ISIC_6307649
# ⚠️ Skipping duplicate: ISIC_6334282
# ⚠️ Skipping duplicate: ISIC_6367358
# ⚠️ Skipping duplicate: ISIC_6382027
# ⚠️ Skipping duplicate: ISIC_6396067
# ⚠️ Skipping duplicate: ISIC_6397037
# ⚠️ Skipping duplicate: ISIC_6399573
# ⚠️ Skipping duplicate: ISIC_6424909
# ⚠️ Skipping duplicate: ISIC_6429128
# ⚠️ Skipping duplicate: ISIC_6465391
# ⚠️ Skipping duplicate: ISIC_6507199
# ⚠️ Skipping duplicate: ISIC_6526733
# ⚠️ Skipping duplicate: ISIC_6545784
# ⚠️ Skipping duplicate: ISIC_6561814
# ⚠️ Skipping duplicate: ISIC_6608075
# ⚠️ Skipping duplicate: ISIC_6621818
# ⚠️ Skipping duplicate: ISIC_6665759
# ⚠️ Skipping duplicate: ISIC_6784337
# ⚠️ Skipping duplicate: ISIC_6798316
# ⚠️ Skipping duplicate: ISIC_6798815
# ⚠️ Skipping duplicate: ISIC_6855233
# ⚠️ Skipping duplicate: ISIC_7026299
# ⚠️ Skipping duplicate: ISIC_7031844
# ⚠️ Skipping duplicate: ISIC_7052130
# ⚠️ Skipping duplicate: ISIC_7054085
# ⚠️ Skipping duplicate: ISIC_7074027
# ⚠️ Skipping duplicate: ISIC_7105211
# ⚠️ Skipping duplicate: ISIC_7160427
# ⚠️ Skipping duplicate: ISIC_7188117
# ⚠️ Skipping duplicate: ISIC_7203136
# ⚠️ Skipping duplicate: ISIC_7285904
# ⚠️ Skipping duplicate: ISIC_7294678
# ⚠️ Skipping duplicate: ISIC_7307297
# ⚠️ Skipping duplicate: ISIC_7314073
# ⚠️ Skipping duplicate: ISIC_7316504
# ⚠️ Skipping duplicate: ISIC_7323467
# ⚠️ Skipping duplicate: ISIC_7324912
# ⚠️ Skipping duplicate: ISIC_7373227
# ⚠️ Skipping duplicate: ISIC_7379567
# ⚠️ Skipping duplicate: ISIC_7400037
# ⚠️ Skipping duplicate: ISIC_7413005
# ⚠️ Skipping duplicate: ISIC_7417402
# ⚠️ Skipping duplicate: ISIC_7420584
# ⚠️ Skipping duplicate: ISIC_7445958
# ⚠️ Skipping duplicate: ISIC_7450066
# ⚠️ Skipping duplicate: ISIC_7464445
# ⚠️ Skipping duplicate: ISIC_7491017
# ⚠️ Skipping duplicate: ISIC_7499766
# ⚠️ Skipping duplicate: ISIC_7538059
# ⚠️ Skipping duplicate: ISIC_7575093
# ⚠️ Skipping duplicate: ISIC_7583570
# ⚠️ Skipping duplicate: ISIC_7606683
# ⚠️ Skipping duplicate: ISIC_7647494
# ⚠️ Skipping duplicate: ISIC_7655277
# ⚠️ Skipping duplicate: ISIC_7676691
# ⚠️ Skipping duplicate: ISIC_7703236
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_7726318.jpg
# ⚠️ Skipping duplicate: ISIC_7733594
# ⚠️ Skipping duplicate: ISIC_7745168
# ⚠️ Skipping duplicate: ISIC_7748442
# ⚠️ Skipping duplicate: ISIC_7770173
# ⚠️ Skipping duplicate: ISIC_7834218
# ⚠️ Skipping duplicate: ISIC_7835812
# ⚠️ Skipping duplicate: ISIC_7836717
# ⚠️ Skipping duplicate: ISIC_7928246
# ⚠️ Skipping duplicate: ISIC_7964390
# ⚠️ Skipping duplicate: ISIC_7989726
# ⚠️ Skipping duplicate: ISIC_8078515
# ⚠️ Skipping duplicate: ISIC_8080250
# ⚠️ Skipping duplicate: ISIC_8110460
# ⚠️ Skipping duplicate: ISIC_8137894
# ⚠️ Skipping duplicate: ISIC_8153765
# ⚠️ Skipping duplicate: ISIC_8269383
# ⚠️ Skipping duplicate: ISIC_8310505
# ⚠️ Skipping duplicate: ISIC_8333431
# ⚠️ Skipping duplicate: ISIC_8336318
# ⚠️ Skipping duplicate: ISIC_8363981
# ⚠️ Skipping duplicate: ISIC_8370313
# ⚠️ Skipping duplicate: ISIC_8386743
# ⚠️ Skipping duplicate: ISIC_8404669
# ⚠️ Skipping duplicate: ISIC_8412135
# ⚠️ Skipping duplicate: ISIC_8440077
# ⚠️ Skipping duplicate: ISIC_8460937
# ⚠️ Skipping duplicate: ISIC_8487444
# ⚠️ Skipping duplicate: ISIC_8512129
# ⚠️ Skipping duplicate: ISIC_8520464
# ⚠️ Skipping duplicate: ISIC_8521796
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_8538214.jpg
# ⚠️ Skipping duplicate: ISIC_8546843
# ⚠️ Skipping duplicate: ISIC_8569576
# ⚠️ Skipping duplicate: ISIC_8614100
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_8634483.jpg
# ⚠️ Skipping duplicate: ISIC_8662001
# ⚠️ Skipping duplicate: ISIC_8731383
# ⚠️ Skipping duplicate: ISIC_8800250
# ⚠️ Skipping duplicate: ISIC_8832909
# ⚠️ Skipping duplicate: ISIC_8850488
# ⚠️ Skipping duplicate: ISIC_8852993
# ⚠️ Skipping duplicate: ISIC_8898380
# ⚠️ Skipping duplicate: ISIC_8899671
# ⚠️ Skipping duplicate: ISIC_8952587
# ⚠️ Skipping duplicate: ISIC_8966407
# ⚠️ Skipping duplicate: ISIC_9060519
# ⚠️ Skipping duplicate: ISIC_9078874
# ⚠️ Skipping duplicate: ISIC_9090322
# ⚠️ Skipping duplicate: ISIC_9127831
# ⚠️ Skipping duplicate: ISIC_9140699
# ⚠️ Skipping duplicate: ISIC_9194166
# ⚠️ Skipping duplicate: ISIC_9207822
# ⚠️ Skipping duplicate: ISIC_9360322
# ⚠️ Skipping duplicate: ISIC_9420821
# ⚠️ Skipping duplicate: ISIC_9452490
# ⚠️ Skipping duplicate: ISIC_9454701
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_9465412.jpg
# ⚠️ Skipping duplicate: ISIC_9521124
# ⚠️ Skipping duplicate: ISIC_9544804
# ⚠️ Skipping duplicate: ISIC_9615085
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_9633302.jpg
# ⚠️ Skipping duplicate: ISIC_9690994
# ⚠️ Skipping duplicate: ISIC_9726753
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_9733341.jpg
# ⚠️ Skipping duplicate: ISIC_9735344
# ⚠️ Skipping duplicate: ISIC_9762220
# ⚠️ Skipping duplicate: ISIC_9805656
# ⚠️ Skipping duplicate: ISIC_9821013
# ⚠️ Skipping duplicate: ISIC_9855202
# ❌ Missing file: /Users/eduardfer/Desktop/Big Data Analytics - UC3M/Machine Learning/KaggleISIC/data/raw/ISIC-images/ISIC_9875351.jpg
# ⚠️ Skipping duplicate: ISIC_9972649
# ⚠️ Skipping duplicate: ISIC_9972877
# ⚠️ Skipping duplicate: ISIC_9996602
# ✅ Done updating HDF5 with new images.
